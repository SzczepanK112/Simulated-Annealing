# %% [markdown]
# ## Przykładowe grafy - utworzone ręcznie

# %%
from struktury_danych import *
from wczytanie_mapy import *
from solution import *

# %% [markdown]
# ## 1.

# %%
nazwa_pliku = 'rozklad_ulic.txt' 
graf = wczytaj_graf_z_pliku(nazwa_pliku)

# Rysowanie grafu

graf.rysuj(decimal_places=0)

# %% [markdown]
# ## 2.

# %%
nazwa_pliku = 'rozklad_ulic_2.txt' 
graf = wczytaj_graf_z_pliku(nazwa_pliku)

# Rysowanie grafu

graf.rysuj(decimal_places=0)
